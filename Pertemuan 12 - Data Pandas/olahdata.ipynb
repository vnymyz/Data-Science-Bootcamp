# %% [markdown]
# # Pertemuan 12
# ********

# %% [markdown]
# # Pandas 2 - Pengolahan Data
# *****

# %% [markdown]
# ## Materi yang akan dibahas
# 1.	Filtering dan Conditional Selection
#
# 2.	Sorting dan Indexing
#
# 3.	Menangani Missing Value
#
# 4.	Menambah/Mengubah Kolom
#
# 5.	Renaming & Reordering Columns
# ********

# %% [markdown]
# ## 1. Filtering dan Conditional Selection
# Filtering digunakan untuk menyaring baris berdasarkan kondisi tertentu.
#
# Conditional Selection memungkinkan kita mengambil subset data berdasarkan kriteria logis (misalnya: usia > 30 atau jenis kelamin perempuan).
#
# Seperti menyaring siswa dari kelas berdasarkan nilai di atas 80 dan jenis kelamin perempuan. Kita hanya ambil yang memenuhi syarat saja.

# %% [markdown]
# ### Filter by 1 condition

# %%
import pandas as pd

df = pd.read_csv('train.csv')

# %%
# Filter 1 Kondisi
# menampilkan data yang umurnya atau Age > 30
df[df['Age'] > 30]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# 11            12         1       1
# ..           ...       ...     ...
# 873          874         0       3
# 879          880         1       1
# 881          882         0       3
# 885          886         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### Filter by 2 condition or more

# %%
# Filter 2 kondisi atau lebih
# AND
# Menampilkan perempuan yang umur nya lebih dari 30
df[(df['Age'] > 20) & (df['Sex'] == 'female')]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 874          875         1       2
# 879          880         1       1
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Tampilkan penumpang wanita di kelas 1
df[(df['Sex'] == 'female') & (df['Pclass'] == 1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 11            12         1       1
# 31            32         1       1
# 52            53         1       1
# ..           ...       ...     ...
# 856          857         1       1
# 862          863         1       1
# 871          872         1       1
# 879          880         1       1
# 887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Tampilkan penumpang pria yang membayar tarif (Fare) di atas 100
df[(df['Sex'] == 'male') & (df['Fare'] > 100)]
# Out:
#      PassengerId  Survived  Pclass  \
# 27            28         0       1
# 118          119         0       1
# 305          306         1       1
# 332          333         0       1
# 373          374         0       1
# 377          378         0       1
# 390          391         1       1
# 438          439         0       1
# 505          506         0       1
# 527          528         0       1
# 544          545         0       1
# 550          551         1       1
# 557          558         0       1
# 659          660         0       1
# 660          661         1       1
# 679          680         1       1
# 698          699         0       1
# 737          738         1       1
# 802          803         1       1
#
#                                            Name   Sex    Age  SibSp  Parch  \
# 27               Fortune, Mr. Charles Alexander  male  19.00      3      2
# 118                    Baxter, Mr. Quigg Edmond  male  24.00      0      1
# ...

# %%
# AND
# Menampilkan umur yang dibawah 18 pada kelas 1
df[(df['Age'] < 18) & (df['Pclass'] == 1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 297          298         0       1
# 305          306         1       1
# 307          308         1       1
# 329          330         1       1
# 435          436         1       1
# 445          446         1       1
# 504          505         1       1
# 550          551         1       1
# 689          690         1       1
# 781          782         1       1
# 802          803         1       1
# 853          854         1       1
#
#                                                   Name     Sex    Age  SibSp  \
# 297                       Allison, Miss. Helen Loraine  female   2.00      1
# 305                     Allison, Master. Hudson Trevor    male   0.92      1
# 307  Penasco y Castellana, Mrs. Victor de Satode (M...  female  17.00      1
# 329                       Hippach, Miss. Jean Gertrude  female  16.00      0
# 435                          Carter, Miss. Lucile Polk  female  14.00      1
# ...

# %%
# OR
# Penumpang dengan umur di bawah 18 atau kelas 1
df[(df['Age'] < 18) | (df['Pclass'] == 1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 7              8         0       3
# 9             10         1       2
# ..           ...       ...     ...
# 872          873         0       1
# 875          876         1       3
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 7                       Palsson, Master. Gosta Leonard    male   2.0      3
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# Kenapa dia nampilin semuanya dan enggak sesuai dengan kondisi ?
#
# Seharusnya dia nampilin Age < 18 dan Pclass == 1
#
# Kita menggunakan OR maka hasilnya :
#
# - Penumpang umur > 18 tapi kelas 1 → ditampilkan ✅
#
# - Penumpang umur < 18 tapi kelasnya bukan 1 → tetap ditampilkan ✅
#
# - Kalau dua-duanya terpenuhi → ya makin oke, tetap ditampilkan juga ✅

# %% [markdown]
# ### .isin()
#  digunakan untuk mengecek apakah nilai di dalam suatu kolom cocok dengan daftar nilai tertentu.

# %%
# Struktur nya aja
DataFrame['kolom'].isin([nilai1, nilai2, ...])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Struktur
# ----> 2 DataFrame['kolom'].isin([nilai1, nilai2, ...])
#
# NameError: name 'DataFrame' is not defined

# %% [markdown]
# - Akan menghasilkan True atau False untuk setiap baris.
#
# - Digunakan untuk filtering (menyaring data) berdasarkan beberapa kondisi nilai.

# %%
# Menyaring data dengan Pclass 1 atau 2
df_filtered = df[df['Pclass'].isin([1, 2])]

# Tampilkan hasil
df_filtered[['PassengerId', 'Pclass']].head()
# Out:
#     PassengerId  Pclass
# 1             2       1
# 3             4       1
# 6             7       1
# 9            10       2
# 11           12       1

# %% [markdown]
# ### Kapan isin() digunakan ?
#
# Saat ingin mencari baris dengan nilai tertentu di kolom tertentu.
#
# Lebih ringkas daripada menulis banyak kondisi or:

# %%
df[(df['Pclass'] == 1) | (df['Pclass'] == 2)]

# %%
# Bisa diganti dengan
df[df['Pclass'].isin([1, 2])]

# %% [markdown]
# ### Filter by String

# %%
# Filter by string
df[df['Name'].str.contains("William")]

# %% [markdown]
# ### Negasi (~)

# %% [markdown]
# Negasi artinya kebalikan dari kondisi yang diberikan.
#
# Simbol negasi di Pandas adalah ~ (tilde).
#
# Mirip kayak Boolean NOT.
#
# Misalnya :
# - df['Cabin'].isna() → menghasilkan baris yang Cabin-nya kosong (NaN)
#
# - ~df['Cabin'].isna() → menghasilkan baris yang Cabin-nya TIDAK kosong

# %%
# Baris yang Cabin-nya kosong
df[df['Cabin'].isna()]

# %%
# Baris yang Cabin-nya TIDAK kosong (pakai negasi ~)
df[~df['Cabin'].isna()]

# %%
# Semua penumpang yang BUKAN laki-laki
df[~(df['Sex'] == 'female')]  # Sama dengan df[df['Sex'] != 'male']

# %%
# Penumpang yang bukan laki-laki
df[df['Sex'] != 'female']

# %% [markdown]
# ### Multiple Condition
#
# - AND: (cond1) & (cond2)
#
# - OR: (cond1) | (cond2)
#
# - Gunakan tanda kurung ( ) untuk tiap kondisi.

# %% [markdown]
# ## 2. Sorting dan Indexing

# %% [markdown]
# ### Sort_values()
#
# Digunakan untuk menyortir berdasarkan nilai kolom

# %%
# Bentuk nya saja
df.sort_values(by='NamaKolom', ascending=True/False)

# %%
# Urut dari umur termuda
df.sort_values(by='Age', ascending=True)

# %%
# Mengurutkan data dari umur tertua
df.sort_values(by='Age', ascending=False)

# %%
# Urut dari harga tiket tertinggi
df.sort_values(by='Fare', ascending=True)

# %%
# Urut dari harga tiket terendah
df.sort_values(by='Fare', ascending=True)

# %%
# Multi Kolom
# Urut berdasarkan kelas (1,2,3), lalu dari umur tertua
df.sort_values(by=['Pclass', 'Age', 'Fare'], ascending=[False, True, True])

# %% [markdown]
# ### Sort_index()
#
# - untuk menyortir berdasarkan index (baris)
#
# - Biasanya dipakai kalau index-nya udah meaningful, atau ingin reset ke urutan awal.

# %%
# sort index berurutan dari A - Z
df.sort_index(ascending=False)

# %%
# sort index kebalikannya
df.sort_index(ascending=False)

# %% [markdown]
# ### Set_index()
#
# Menjadikan kolom sebagai index
#
# default index yaitu 0, 1, 2 ,3 , 4, 5....

# %%
# Sebelum set index
import pandas as pd

# Contoh mini DataFrame seperti Titanic
data = {
    'PassengerId': [1, 2, 3],
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 22]
}

df = pd.DataFrame(data)

print("DataFrame Awal: ")
df

# %%
# Set index
df.set_index('PassengerId', inplace=False)

print("\nSetelah set_index('PassengerId'):")
df

# %%
# reset index untuk mengembalikkan index menjadi semula
df.reset_index()
df.head()

# %%
import pandas as pd

df = pd.read_csv('train.csv')

# %%
# cek data awal train
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Set index
df.set_index('PassengerId', inplace=True)
df.head()  # Tabel dengan PassengerId sebagai index
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
# Reset Index
df.reset_index(inplace=True)
df.head()  # Sekarang PassengerId jadi kolom biasa lagi
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# | Fungsi          | Tujuan                              | Mengubah Struktur Index? | Keterangan Tambahan                                   |
# | --------------- | ----------------------------------- | ------------------------ | ----------------------------------------------------- |
# | `set_index()`   | Mengganti kolom jadi index          | ✅ Ya                     | Menjadikan kolom sebagai index DataFrame              |
# | `sort_values()` | Mengurutkan berdasarkan nilai kolom | ❌ Tidak                  | Mengurutkan berdasarkan nilai di kolom tertentu       |
# | `sort_index()`  | Mengurutkan berdasarkan nilai index | ❌ Tidak                  | Hanya mengurutkan berdasarkan index (bukan isi kolom) |

# %% [markdown]
# ## 3. Menangani Missing Value
# Missing value adalah data yang kosong atau tidak terisi, biasanya terlihat sebagai NaN (Not a Number) di pandas.
#
# Missing value artinya ada data yang kosong atau hilang dalam sebuah kolom. Dalam Pandas, ini ditandai dengan NaN (Not a Number).

# %% [markdown]
# | Fungsi             | Kegunaan                                                      |
# | ------------------ | ------------------------------------------------------------- |
# | `dropna()`         | Menghapus baris/kolom yang mengandung `NaN`                   |
# | `fillna()`         | Mengisi nilai yang hilang dengan nilai tertentu               |
# | Imputasi sederhana | Mengisi `NaN` dengan rata-rata, median, modus, atau konstanta |

# %%
import pandas as pd

# Load dataset
df = pd.read_csv('train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Cek jumlah missing value di tiap kolom
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ### Dropna()

# %%
# Hapus baris yang punya data kosong
# Untuk menghapus baris atau kolom yang memiliki NaN.
# Semua baris yang punya nilai kosong di kolom manapun akan dihapus.

df_bersih = df.dropna() #ngebersihin semuanya

# %%
# Cek apakah masih ada NaN
df_bersih.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
# Hapus baris jika kolom tertentu saja yang kosong
# Ini hanya menghapus baris kalau kolom Age-nya kosong.
# Artinya kamu menghapus baris hanya jika nilai pada kolom Age kosong (NaN), tanpa menyentuh kolom lain.
df_tanpa_age = df.dropna(subset=['Age'])

# %%
print("Jumlah baris sebelum di-drop:", len(df))
print("Jumlah baris setelah drop Age NaN:", len(df_tanpa_age))
# Out:
# Jumlah baris sebelum di-drop: 891
# Jumlah baris setelah drop Age NaN: 714

# %% [markdown]
# ### Fillna()

# %%
# Isi missing value kolom Age dengan nilai rata-rata
rata_rata_age = df['Age'].mean()
df['Age'] = df['Age'].fillna(rata_rata_age)

print("Jumlah missing value di kolom Age setelah fillna:", df['Age'].isnull().sum())
print("Nilai rata-rata Age yang digunakan:", rata_rata_age)
# Out:
# Jumlah missing value di kolom Age setelah fillna: 0
# Nilai rata-rata Age yang digunakan: 29.69911764705882

# %%
# Cek apakah NaN sudah berubah jadi mean
df[df['Age'] == rata_rata_age].head()
# Out:
#     PassengerId  Survived  Pclass                           Name     Sex  \
# 5             6         0       3               Moran, Mr. James    male
# 17           18         1       2   Williams, Mr. Charles Eugene    male
# 19           20         1       3        Masselmani, Mrs. Fatima  female
# 26           27         0       3        Emir, Mr. Farred Chehab    male
# 28           29         1       3  O'Dwyer, Miss. Ellen "Nellie"  female
#
#           Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 5   29.699118      0      0  330877   8.4583   NaN        Q
# 17  29.699118      0      0  244373  13.0000   NaN        S
# 19  29.699118      0      0    2649   7.2250   NaN        C
# 26  29.699118      0      0    2631   7.2250   NaN        C
# 28  29.699118      0      0  330959   7.8792   NaN        Q

# %%
#  Isi missing value kolom Embarked dengan 'S'
df['Embarked'] = df['Embarked'].fillna('S')

# %%
df[df['Embarked'].notnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %% [markdown]
# | Fungsi     | Tujuan                                    | Risiko                                |
# | ---------- | ----------------------------------------- | ------------------------------------- |
# | `dropna()` | Menghapus data kosong                     | Bisa kehilangan banyak data penting   |
# | `fillna()` | Mengisi data kosong dengan nilai tertentu | Bisa bias kalau nilai pengganti salah |

# %% [markdown]
# ## 4. Menambah dan Mengubah Kolom

# %% [markdown]
# Kita bisa menambah kolom baru dari perhitungan, atau mengubah isi kolom yang sudah ada.
#
# Analogi nya : Menambahkan kolom ‘Total Nilai’ dari jumlah nilai UTS dan UAS.

# %% [markdown]
# ### Menambah Kolom Baru

# %%
import pandas as pd

# Load dataset
df = pd.read_csv('train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Kolom baru bernama FamilySize = SibSp + Parch + 1
df['FamilySize'] = df['SibSp'] + df['Parch'] + 1 
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  FamilySize
# 0      0         A/5 21171   7.2500   NaN        S           2
# 1      0          PC 17599  71.2833   C85        C           2
# 2      0  STON/O2. 3101282   7.9250   NaN        S           1
# ...

# %%
# Kolom IsAlone → 1 jika sendirian, 0 jika ada keluarga
df['IsAlone'] = 0
df.loc[df['FamilySize'] == 1, 'IsAlone'] = 1
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  FamilySize  IsAlone
# 0      0         A/5 21171   7.2500   NaN        S           2        0
# 1      0          PC 17599  71.2833   C85        C           2        0
# 2      0  STON/O2. 3101282   7.9250   NaN        S           1        1
# ...

# %% [markdown]
# ### Mengubah Nilai di Kolom yang Sudah Ada

# %%
# Contoh: Ubah isi kolom Sex dari 'male'/'female' → 0/1
df['Sex'] = df['Sex'].map({'male': 0, 'female': 1})
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  FamilySize  IsAlone
# 0         A/5 21171   7.2500   NaN        S           2        0
# 1          PC 17599  71.2833   C85        C           2        0
# 2  STON/O2. 3101282   7.9250   NaN        S           1        1
# ...

# %%
# atau bisa
df['Sex'] = df['Sex'].replace(['male', 'female'], [0, 1])
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  FamilySize  IsAlone
# 0         A/5 21171   7.2500   NaN        S           2        0
# 1          PC 17599  71.2833   C85        C           2        0
# 2  STON/O2. 3101282   7.9250   NaN        S           1        1
# ...

# %%
# Binning Kolom Age Menjadi Kategori
def age_category(age):
    if age < 12:
        return 'Child'
    elif age < 18:
        return 'Teen'
    elif age < 60:
        return 'Adult'
    else:
        return 'Senior'

df['AgeCategory'] = df['Age'].apply(age_category)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    0  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1
# 2                               Heikkinen, Miss. Laina    1  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1
# 4                             Allen, Mr. William Henry    0  35.0      0
# ..                                                 ...  ...   ...    ...
# ...

# %% [markdown]
# ## 5. Rename dan Reorder Columns

# %% [markdown]
# Kadang kita perlu mengganti nama kolom agar lebih deskriptif atau menyusun ulang kolom agar lebih rapi.
#
# Analogi: Mengganti "Nilai" jadi "Skor", atau menyusun kolom dari yang terpenting.

# %% [markdown]
# ### Rename

# %% [markdown]
# Mengganti nama kolom agar lebih deskriptif, konsisten, atau mudah dipahami.

# %%
# Bentuk strukturnya
DataFrame.rename(columns={'nama_lama': 'nama_baru'}, inplace=False)

# %% [markdown]
# - columns: dictionary yang berisi pasangan kolom_lama: kolom_baru.
#
# - inplace=True: langsung mengubah di DataFrame asli.
#
# - inplace=False: mengembalikan DataFrame baru (default).

# %%
import pandas as pd

# Load dataset
df = pd.read_csv('train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# mengganti kolom 'Sex' menjadi 'Gender' dan 'Fare' menjadi 'TicketPrice'
df_renamed = df.rename(columns={'Sex': 'Gender', 'Fare': 'TicketPrice', 'PassengerId': 'ID'})

# hasil
df_renamed[['Gender', 'TicketPrice', 'ID']].head()
# Out:
#    Gender  TicketPrice
# 0    male       7.2500
# 1  female      71.2833
# 2  female       7.9250
# 3  female      53.1000
# 4    male       8.0500

# %% [markdown]
# ### Reordering Columns
#
# Membuat tampilan DataFrame lebih logis atau fokus hanya pada kolom-kolom penting.
#
# Buat ulang urutan kolom dengan menyusun ulang nama-nama kolom.

# %%
# Tampilkan kolom yang tersedia terlebih dahulu
print(df.columns.tolist())

# %%
# Setelah rename 'Sex' menjadi 'Gender' dan 'Fare' menjadi 'TicketPrice'
df_renamed = df.rename(columns={'Sex': 'Gender', 'Fare': 'TicketPrice'})
df_renamed.head()

# %%
# Reorder kolom sesuai kebutuhan
df_reordered = df_renamed[['PassengerId', 'Name', 'Gender', 'Age', 'Pclass', 'TicketPrice']]

# Tampilkan hasil
df_reordered.head()

# %% [markdown]
# ## Kesimpulan
#
# | Materi             | Tujuan                            | Aplikasi Dunia Kerja                   |
# | ------------------ | --------------------------------- | -------------------------------------- |
# | Filtering          | Menyaring data berdasarkan syarat | Customer segmentation, fraud detection |
# | Sorting & Indexing | Menyusun dan mengelola data       | Data ranking, report generation        |
# | Missing Values     | Menangani data kosong             | Data cleaning sebelum training model   |
# | Tambah/Ubah Kolom  | Buat fitur baru dari kolom lama   | Feature engineering                    |
# | Rename/Reorder     | Rapikan dan standarisasi kolom    | Integrasi data antar tim/departemen    |

# %% [markdown]
# ----

# %% [markdown]
# ## Latihan

# %%
import pandas as pd

df = pd.read_csv('train.csv')

# %% [markdown]
# ### Soal 1
# Tampilkan seluruh data penumpang yang:
#
# Berjenis kelamin perempuan (Sex == 'female')
#
# Berusia di bawah 30 tahun (Age < 30)
#
# Berangkat dari pelabuhan Southampton (Embarked == 'S')

# %%
# write your code here
df_filtered = df[(df['Sex'] == 'female') & (df['Age'] < 30) & (df['Embarked'] == 'S')]
df_filtered.head()

# %% [markdown]
# ### Soal 2
# Urutkan data berdasarkan kolom Fare dari yang paling mahal ke paling murah, lalu tampilkan 5 penumpang teratas.

# %%
# Write your code here
df_sorted = df.sort_values(by='Fare', ascending=False)
df_sorted.head()

# %% [markdown]
# ### Soal 3
# Ubah kolom PassengerId menjadi index baru, lalu tampilkan data penumpang dengan PassengerId 100.

# %%
# Write your code here
df_indexed = df.set_index('PassengerId')
df_indexed

# %%
df_indexed.loc[100]

# %% [markdown]
# ### Soal 4
# Hitung total data kosong (missing value) di setiap kolom.

# %%
# Write your code here
df.isnull().sum()

# %% [markdown]
# ### Soal 5
# Isi nilai kosong pada kolom Age dengan median, bukan mean.

# %%
# Write your code here
median_age = df['Age'].median()
df['Age'] = df['Age'].fillna(median_age)

# %% [markdown]
# ### Soal 6
# Tambahkan kolom baru bernama FamilySize yang merupakan jumlah dari SibSp dan Parch.

# %%
# Write your code here
df['FamilySize'] = df['SibSp'] + df['Parch']

# %% [markdown]
# ### Soal 7
# Buat kolom baru IsAlone bernilai:
#
# 1 jika FamilySize == 0
#
# 0 jika tidak

# %%
# Write your code here
df['IsAlone'] = df['FamilySize'].apply(lambda x: 1 if x == 0 else 0)

# %% [markdown]
# ### Soal 8
# Ubah nama kolom:
#
# SibSp → SiblingsSpouses
#
# Parch → ParentsChildren

# %%
# Write your code here
df.rename(columns={'SibSp': 'SiblingsSpouses', 'Parch': 'ParentsChildren'}, inplace=True)

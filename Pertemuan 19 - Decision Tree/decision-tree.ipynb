# %% [markdown]
# # Pertemuan 19 - Data Science Bootcamp
# ---
# ## Decision Tree
# ---

# %% [markdown]
# ### 1. Apa itu Decision Tree ?
#
# nanti jelasin. Decision Tree dapat menyelesaikan permasalahn seperti Regression dan Classification.
#
# ### 1.1 Decision Tree Classifier
#
# Decision tree menggunakan classifier yaitu ID3 dan CART.
#
# ### a. ID3
#
# jelasin ini apa. ID3 buat nentuin binary tree lebih banyak dibanding CART.
#
# ### b. CART
#
# jelasin cart apa. CART ini membuat binary tree aja.
#
# ### 1.2 Entropy and Gini Index
#
# Untuk menentukan Purity Split. Tujuan dari Entropi dan Gini index adalah untuk menentukan suatu Node itu Impure atau pure dalam arti :
#
# - Impure itu yang masih ada tree nodes nya atau Yes or No nya masing2 ada seperti 4 yes and 3 no.
#
# - Pure itu yang bener2 udah leaf node aja seperti 4 yes dan 0 no.
#
# ### 1.3 Information Gain
#
# - Untuk menentukan fitur apa yang digunakan sebagai fitur utama dalam decision tree.
#
# - Fitur apa yang perlu di pilih buat splitting ?
#
# ### 1.4 Decision tree itu seperti if else
#
# Misal :
#
# ```python
# age = 14
#
# if (age <= 15):
#     print("Dia masih Sekolah")
# elif (age > 15 and age <= 21):
#     print("Dia kemungkinan ")
# else :
#     print("Dia sudah lulus kuliah")
# ```
#
# Jika dibuat dalam bentuk Decision tree :
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 1.5 Implementasi visual decision tree

# %% [markdown]
# Dataset (Binary Classification):
#
# ![image.png](attachment:image.png)
#
# Decision Tree :
#
# ![image-2.png](attachment:image-2.png)
#
# Untuk menentukan Purity yaitu menggunakan 2 teknik :
#
# 1. Entropy
#
# 2. Gini Impurity
#
# Untuk menentukan fitur apa yang perlu dipilih yaitu menggunakan information gain untuk melakukan splitting.

# %% [markdown]
# ---

# %% [markdown]
# ### 2. Entropy dan Gini Impurity
